# %% [markdown]
# # Imports & Setup

# %% [markdown]
# Download all the necessary dependencies. These should be exactly the ones present in the `environment.yaml` file.

# %%
# !pip -q install numpy tqdm pandas transformers accelerate bitsandbytes
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.6/302.6 kB 5.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 MB 6.8 MB/s eta 0:00:00

# %%
#!pip -q install accelerate
# !pip -q install bitsandbytes

# %%
# !git clone https://github.com/prundeanualin/ATCS-project.git
# Out:
# Cloning into 'ATCS-project'...
# remote: Enumerating objects: 87, done.
# remote: Counting objects: 100% (87/87), done.
# remote: Compressing objects: 100% (69/69), done.
# remote: Total 87 (delta 22), reused 46 (delta 13), pack-reused 0
# Receiving objects: 100% (87/87), 43.01 KiB | 1.72 MiB/s, done.
# Resolving deltas: 100% (22/22), done.
# fatal: not a git repository (or any of the parent directories): .git

# %%
# IF YOU WANT TO TEST THINGS FROM YOUR OWN BRANCH, UNCOMMENT BELOW
# ! git checkout <your_own_branch>
# Out:
# Branch 'first_run' set up to track remote branch 'first_run' from 'origin'.
# Switched to a new branch 'first_run'

# %%
# ! git status
# Out:
# On branch first_run
# Your branch is up to date with 'origin/first_run'.
#
# nothing to commit, working tree clean

# %%
# !unzip ATCS-project-main.zip
# Out:
# Archive:  ATCS-project-main.zip
#    creating: ATCS-project-main/
#   inflating: __MACOSX/._ATCS-project-main
#   inflating: ATCS-project-main/run.py
#   inflating: __MACOSX/ATCS-project-main/._run.py
#   inflating: ATCS-project-main/.DS_Store
#   inflating: __MACOSX/ATCS-project-main/._.DS_Store
#   inflating: ATCS-project-main/LICENSE
#   inflating: __MACOSX/ATCS-project-main/._LICENSE
#   inflating: ATCS-project-main/datasets.py
#   inflating: __MACOSX/ATCS-project-main/._datasets.py
#   inflating: ATCS-project-main/model.py
#   inflating: __MACOSX/ATCS-project-main/._model.py
#   inflating: ATCS-project-main/README.md
#   inflating: __MACOSX/ATCS-project-main/._README.md
#   inflating: ATCS-project-main/.gitignore
#   inflating: __MACOSX/ATCS-project-main/._.gitignore
#   inflating: ATCS-project-main/utils.py
#   inflating: __MACOSX/ATCS-project-main/._utils.py
#   inflating: ATCS-project-main/environment.yaml
#   inflating: __MACOSX/ATCS-project-main/._environment.yaml
#    creating: ATCS-project-main/data/
#   inflating: __MACOSX/ATCS-project-main/._data
#    creating: ATCS-project-main/prompt_templates/
#   inflating: __MACOSX/ATCS-project-main/._prompt_templates
#   inflating: ATCS-project-main/get_datasets.py
#   inflating: __MACOSX/ATCS-project-main/._get_datasets.py
#   inflating: ATCS-project-main/CoT Analogy Resolution.ipynb
#   inflating: __MACOSX/ATCS-project-main/._CoT Analogy Resolution.ipynb
#    creating: ATCS-project-main/data/BATS/
#   inflating: ATCS-project-main/data/.DS_Store
#   inflating: __MACOSX/ATCS-project-main/data/._.DS_Store
#    creating: ATCS-project-main/data/SCAN/
#   inflating: __MACOSX/ATCS-project-main/data/._SCAN
#   inflating: ATCS-project-main/prompt_templates/analogy.py
#   inflating: __MACOSX/ATCS-project-main/prompt_templates/._analogy.py
#   inflating: ATCS-project-main/data/BATS/L01 [hypernyms - animals] sample.txt
#   inflating: __MACOSX/ATCS-project-main/data/BATS/._L01 [hypernyms - animals] sample.txt
#   inflating: ATCS-project-main/data/SCAN/SCAN_examples_baseline.txt
#   inflating: __MACOSX/ATCS-project-main/data/SCAN/._SCAN_examples_baseline.txt

# %%
pwd
# Out:
# '/content'

# %%
# %cd /content/ATCS-project-main
# Out:
# /content/ATCS-project-main

# %%
import argparse

from get_datasets import SCAN_EXAMPLES_FILEPATH, EXAMPLE_CATEGORIES
from prompt_templates.analogy import ANALOGY_TEMPLATE_SIMPLE_INFERENCE, ANALOGY_TEMPLATE_SIMPLE_FULL
from model import LLMObj
import torch
from tqdm import tqdm
from transformers import BitsAndBytesConfig
import pickle
from datasets import ScanDataset
import os

from utils import seed_experiments

os.environ['HF_TOKEN'] = "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"
os.environ['HF_HUB_ENABLE_HF_TRANSFER'] = '1'

torch.set_default_device('cuda')

# %% [markdown]
# # Inference
#
# `LLMObj` is a HF wrapper that contains the LLM model, tokenizer, and text generation wrapper.
#
# Below the class code, several LLMs that are available on HF are initialized.
#
# For some models like LLama, you need to authenticate your HF account, so add your [HF access token](https://huggingface.co/docs/hub/security-tokens) to the secrets on secrets as `HF_TOKEN`.

# %% [markdown]
# ## Model arguments

# %%
# Since ArgParser does not work in colab, we just construct a custom class with all our neccessary arguments
class Args(argparse.Namespace):
  model = "microsoft/Phi-3-mini-128k-instruct"
  tokenizer = "microsoft/Phi-3-mini-128k-instruct"
  quantization = "4bit"
  low_cpu_mem_usage = True
  seed=1234

args = Args()

seed_experiments(args.seed)

# %% [markdown]
# ## Load the dataset
#
# ### SCAN

# %%
# Load the dataset
dataset = ScanDataset(
    shuffle=False,
    analogy_sentence_infer=ANALOGY_TEMPLATE_SIMPLE_INFERENCE,
    analogy_sentence_full=ANALOGY_TEMPLATE_SIMPLE_FULL,
    examples_file=SCAN_EXAMPLES_FILEPATH.format(EXAMPLE_CATEGORIES[0]),
    examples_start_idx=0,
    examples_shot_nr=1
)
# Out:
# SCAN datasets already downloaded.

# %%
for i, sample in tqdm(enumerate(dataset)):
    print(sample)
    break
# Out:
# 0it [00:00, ?it/s]
# {'inference': 'If atom is like solar system, then electron is like...', 'label': 'planet', 'alternatives': [], 'analogy_type': 'science'}

# %% [markdown]
# ### BATS dataset

# %%
from itertools import combinations
import csv
import random
import pickle

BATS_FOLDER = 'data/BATS'
BATS_FILENAME = 'L01 [hypernyms - animals] sample'
COT_TEMPLATE = "Thinking step by step. "


ANALOGY_TEMPLATE_SIMPLE_FULL = "If {} is like {}, then {} is like {}."
ANALOGY_TEMPLATE_SIMPLE_INFERENCE = "If {} is like {}, then {} is like..."

class BATSDataloader_0shot:
    def __init__(self, dataFolder, fileName, numberOfAnalogy = False, cot=False, shuffle=False, promptType="by-relation", promptFormat=" If {} is like {}, {} is like ..."):
        self.dataFolder = dataFolder
        self.fileName = fileName
        self.promptFormat = promptFormat
        start = fileName.find('[') + 1
        end = fileName.find(']')
        self.analogyType = fileName[start:end]
        self.numberOfAnalogy = numberOfAnalogy
        self.promptType = promptType # promptType: by-relation, by-target-word
        self.COT = cot
        self.promptFormat = promptFormat
        self.shuffle = shuffle
        self.load_pairs()
        self.build_prompt()

    def load_pairs(self):
        '''
        Output: pairs = [[target, source, alternatives, analogyType], [target, source, alternatives, analogyType], ...]
        '''
        with open(f'{self.dataFolder}/{self.fileName}.txt', 'r') as f:
            lines = f.readlines()
        self.pairs = []
        for line in lines:
            target, values = line.strip().split('\t')
            values = values.split('/')
            # remove value that have underscore
            values = [value for value in values if '_' not in value]
            # only select the first element in value list as label/attribute, the rest are alternatives
            source = values[0]
            alternatives = [value for value in values[1:] if value]
            self.pairs.append([target, source, alternatives, self.analogyType])

        # # save as csv
        # with open(f'{self.dataFolder}/{self.fileName}_pairs.csv', 'w') as f:
        #     writer = csv.writer(f)
        #     writer.writerow(['target', 'source', 'alternatives', 'analogy_type'])
        #     writer.writerows(self.pairs)

        # save as pickle
        # with open(f'{self.dataFolder}/{self.fileName}_pairs.pkl', 'wb') as f:
        #     pickle.dump(self.pairs, f)


    def build_prompt(self):
        '''
        Output:
        '''
        self.prompt = []
        if self.promptType == "by-relation":
            # combination of 2 pairs and generate prompt
            for pair in combinations(self.pairs, 2):
                # check if same analogy type
                if pair[0][3] != pair[1][3]:
                    continue
                inference = self.promptFormat.format(pair[0][0], pair[0][1], pair[1][0])
                if self.COT:
                    inference = self.COT + inference
                self.prompt.append({'inference': inference, 'label': pair[1][1], 'alternatives': pair[1][2], 'analogy_type': pair[0][3]})
        elif self.promptType == "by-target-word":
            for pair in combinations(self.pairs, 2):
                # check if same analogy type
                if pair[0][3] != pair[1][3]:
                    continue
                inference = self.promptFormat.format(pair[0][0], pair[1][0], pair[0][1])
                if self.COT:
                    inference = self.COT + inference
                self.prompt.append({'inference': inference, 'label': pair[1][1], 'alternatives': pair[1][2], 'analogy_type': pair[0][3]})
        else:
            print("Invalid prompt type. Either by-relation or by-target-word")

        prompt_condition = self.promptFormat.split(",")[0]
        fname = f"0shot_prompt_{self.fileName}_{self.COT if self.COT else 'no_COT'}_{self.promptType}_{prompt_condition}"
        # # save as csv
        # with open(f'{self.dataFolder}/{fname}.csv', 'w') as f:
        #     writer = csv.DictWriter(f, fieldnames=self.prompt[0].keys())
        #     writer.writeheader()
        #     writer.writerows(self.prompt)

        # save as pickle
        # with open(f'{self.dataFolder}/{fname}.pkl', 'wb') as f:
        #     pickle.dump(self.prompt, f)

    def __call__(self):
        if self.shuffle:
            random.seed(42)
            random.shuffle(self.prompt)
        # return only the number of analogy specified (if does not exceed the total number of analogy)
        if self.numberOfAnalogy and self.numberOfAnalogy < len(self.pairs):
            return self.prompt[:self.numberOfAnalogy]
        return self.prompt


BATS_dataset_0 = BATSDataloader_0shot(BATS_FOLDER, BATS_FILENAME, numberOfAnalogy = 2, cot = COT_TEMPLATE, promptType='by-target-word', promptFormat = ANALOGY_TEMPLATE_SIMPLE_INFERENCE)
BATS_dataset_0()
# Out:
# [{'inference': 'Thinking step by step. If allosaurus is like anaconda, then dinosaur is like...',
#   'label': 'snake',
#   'alternatives': ['reptile', 'boa', 'serpent', 'ophidian'],
#   'analogy_type': 'hypernyms - animals'},
#  {'inference': 'Thinking step by step. If allosaurus is like ant, then dinosaur is like...',
#   'label': 'insect',
#   'alternatives': ['invertebrate'],
#   'analogy_type': 'hypernyms - animals'}]

# %%
from tqdm import tqdm
for i, sample in tqdm(enumerate(BATS_dataset())):
  print(sample)
  break
# Out:
# 0it [00:00, ?it/s]
# {'inference': 'Thinking step by step. If allosaurus is like anaconda, then dinosaur is like...', 'label': 'snake', 'alternatives': ['reptile', 'boa', 'serpent', 'ophidian'], 'analogy_type': 'hypernyms - animals'}

# %%
# read csv file and convert to list of dictionary, save as pickle. the header of the csv file is the key of the dictionary

BATS_example_file = 'data/BATS/BATS_example.csv'
BATS_example = []
with open(BATS_example_file, 'r') as f:
    # match line to key-value, with key as header
    reader = csv.reader(f, delimiter=';')
    header = next(reader)
    for line in reader:
        BATS_example.append({k: v for k, v in zip(header, line)})
# save as pickle
with open('data/BATS/BATS_example.pkl', 'wb') as f:
    pickle.dump(BATS_example, f)

# %%
with open('data/BATS/BATS_example.pkl', 'rb') as f:
    BATS_example = pickle.load(f)
for i, sample in enumerate(BATS_example):
    print(sample)
# Out:
# {'word_A': 'cookware', 'word_B': 'pot', 'word_C': 'car', 'label': 'limousine', 'subset': 'hyponyms - misc', 'analogy_type': 'hyponyms', 'baseline': 'pot is hyponyms of cookware. Similarly, limousine is hyponyms of car. Therefore, the answer is limousine', 'short': 'Cookware refers to all kinds of kitchenware and utilities in which food can be cooked, for example, pot and pan. Cookware and pot hence have a whole-part relationship. Similarly, car and limousine also establish a whole-part relationship. Therefore, the answer is limousine. ', 'long': 'Cookware encompasses a broad array of kitchen utensils and equipment utilized for cooking purposes, ranging from pots and pans to skillets and Dutch ovens. Cookware serves as the overarching category, representing the entirety of kitchen tools employed in food preparation. Within this category, a pan functions as a specific subset, constituting one of the primary implements utilized for stovetop cooking, frying, and sautéing. This relationship illustrates a whole-part dynamic, wherein cookware serves as the whole category, encompassing various types of kitchen tools, while pan represents a constituent part within this category, fulfilling specific cooking functions. Similarly, within the domain of transportation, car serves as a general classification encompassing a diverse range of motor vehicles designed for personal or commercial use. It comprises various types such as sedans, hatchbacks, SUVs, and trucks. Among these classifications, a limousine functions as a distinct subset, characterized by its elongated body, luxurious amenities, and chauffeur-driven service. Like the relationship between cookware and pan, the analogy between car and limousine exemplifies a whole-part relationship, with car representing the overarching category of motor vehicles and limousine constituting a specific type or variant within this classification. Therefore, the answer is limousine.', 'detailed': 'Cookware functions as a categorical abstraction encompassing a spectrum of culinary implements utilized for food preparation within domestic or professional settings. Cookware constitutes a high-level taxonomic classification within the domain of kitchen utensils, delineating a comprehensive array of tools designed for cooking, baking, and food processing. From a technical perspective, cookware is designed to efficiently conduct and distribute heat, allowing for the uniform cooking of food. Materials used in cookware construction, such as stainless steel, aluminum, cast iron, and ceramic, are chosen for their heat conductivity properties and durability. Within this abstract framework, a pan assumes the role of a specialized subset, denoting a specific class of cookware characterized by a shallow, flat-bottomed vessel used for heating, frying, and sautéing culinary ingredients. Conversely, in the domain of transportation engineering and taxonomy, car operates as a broad conceptual category encapsulating a diverse range of motorized vehicles designed for terrestrial locomotion. This abstraction encompasses various subcategories, configurations, and design specifications, reflecting the multifaceted nature of automotive engineering. Cars also feature steering systems that enable drivers to control the direction of travel, as well as braking systems for deceleration and stopping. Suspension systems help to absorb shocks and maintain stability, while tires provide traction and grip on the road surface. Additionally, cars are equipped with various safety features such as airbags, seat belts, and collision avoidance systems to protect occupants in the event of an accident. Modern cars also incorporate advanced technologies such as GPS navigation, infotainment systems, and driver assistance features for added convenience and safety. Among these subtypes, a limousine emerges as a distinctive subclassification, distinguished by its elongated chassis, luxurious amenities, and chauffeur-driven service orientation. In ...
# {'word_A': 'jewel', 'word_B': 'diamond', 'word_C': 'painting', 'label': 'watercolor', 'subset': 'hyponyms - misc', 'analogy_type': 'hyponyms', 'baseline': 'diamond is hyponyms of jewel. Similarly, watercolor is hyponyms of painting. Therefore, the answer is watercolor', 'short': 'Just as a diamond is a specific type of jewel known for its brilliance and hardness, a watercolor is a particular type of painting known for its use of water-based pigments and transparent effects. Both pairs exhibit parallel relationships, with one term representing a specific type within a broader category. Therefore, the answer is watercolor.', 'long': 'Jewel encompasses a broad spectrum of precious or semi-precious stones, each with its own unique characteristics and allure. Among these, the diamond stands out as a particularly revered gemstone, renowned for its exceptional brilliance, clarity, and durability. As one of the most coveted gemstones in the world, the diamond holds a special place within the realm of jewels, symbolizing purity, strength, and timeless beauty. Similarly, within the realm of artistic expression, painting serves as a multifaceted medium encompassing various techniques, styles, and materials. From oil and acrylic to watercolor and beyond, painting embodies a diverse array of artistic endeavors aimed at capturing emotion, narrative, and aesthetic beauty. Within this expansive domain, watercolor emerges as a distinct subset characterized by its unique properties and techniques. Unlike other painting mediums, watercolor relies on the transparent pigments suspended in water to create delicate washes, subtle blends, and ethereal effects. Renowned for its fluidity, spontaneity, and luminosity, watercolor painting has a rich history and tradition, beloved by artists and enthusiasts alike for its expressive potential and evocative qualities. In essence, the analogy between jewel and diamond, as well as painting and watercolor, underscores the intricate interplay between broader categories and their specialized subsets. Therefore, the answer is watercolor.', 'detailed': 'Within the field of gemology, a jewel represents a class of gemstones prized for their rarity, beauty, and durability. These gems span a vast spectrum, encompassing diamonds, rubies, sapphires, emeralds, and more. Among them, the diamond stands out as a crystalline form of carbon, renowned for its exceptional hardness, brilliance, and refractive index. Its structure comprises a three-dimensional lattice of carbon atoms bonded tetrahedrally, resulting in its remarkable physical properties, including its ability to refract light and disperse spectral colors. In arts, painting serves as a comprehensive artistic discipline encompassing various mediums, techniques, and styles. From oil and acrylic to watercolor and gouache, painting embodies a diverse array of expressive possibilities. Focusing specifically on watercolor, we encounter a unique painting medium characterized by its aqueous pigments and transparent application. Unlike opaque mediums, watercolor relies on the suspension of finely ground pigment particles in water, with gum arabic or other binders added to stabilize the mixture. When applied to paper or other absorbent surfaces, watercolor pigments interact with the substrate, producing vibrant hues and subtle tonal variations. The translucent nature of watercolor allows for layered washes, delicate glazes, and spontaneous blending, resulting in ethereal, luminous effects prized by artists for centuries. In essence, the analogy between jewel and diamond, as well as painting and watercolor, underscores the intersection of craftsmanship, science, and artistic expression. Furthermore, both pairs exemplify parallel relationships, with one term representing a specific type within a broader category. Therefore, the answer is watercolor.', 'simple': 'Diamond is a type of jewel, an ornament or piece of jewellery containing precious stones. Similarly, watercolor is a ...
# {'word_A': 'sofa', 'word_B': 'divan', 'word_C': 'spice', 'label': 'pepper', 'subset': 'hyponyms - misc', 'analogy_type': 'hyponyms', 'baseline': 'divan is hyponyms of sofa. Similarly, pepper is hyponyms of spice. Therefore, the answer is pepper', 'short': 'Divan is a long, low sofa without the back or arms. Pepper is a specific type of spice, known for its pungent, hot-tasting flavor. Both pairs illustrate whole-part relationships, where later term represents a specific type within a broader category of the former term. Therefore, the answer is pepper. ', 'long': 'A sofa typically refers to a piece of upholstered seating with a backrest and armrests, designed to accommodate multiple people comfortably. A divan is a specific type of sofa characterized by its low seat height, often without a backrest, and may feature a mattress-like cushion for lounging or sleeping.  A divan therefore offers a distinct style and functionality within the broader category of sofas. Similarly, in the culinary domain, spice and pepper exhibit a whole-part relationship. Spice encompasses a vast array of aromatic substances derived from various parts of plants, including seeds, bark, roots, and fruits, used to enhance the flavor and aroma of food. Within this diverse category, pepper stands out as a specific spice, prized for its pungent flavor. In essence, the analogy between sofa and divan, as well as spice and pepper, highlights how one term represents a specialized subset within a broader category. Therefore, the answer is pepper.\n', 'detailed': 'A sofa typically refers to a piece of upholstered seating with a backrest and armrests, designed to accommodate multiple people comfortably. On the other hand, a divan is a specific type of sofa characterized by its low seat height, often without a backrest, and may feature a mattress-like cushion for lounging or sleeping.  A divan therefore offers a distinct style and functionality within the broader category of sofas. Similarly, in the culinary domain, spice and pepper exhibit a parallel relationship. Spice encompasses a vast array of aromatic substances derived from various parts of plants, including seeds, bark, roots, and fruits, used to enhance the flavor and aroma of food. Within this diverse category, pepper stands out as a specific spice derived from the berries of the Piperaceae family plants, notably black pepper (Piper nigrum) and white pepper (Piperaceae Penang). Pepper is prized for its pungent flavor and is one of the most widely used spices globally, adding heat and depth to a wide range of culinary dishes. In essence, the analogy between sofa and divan, as well as spice and pepper, highlights how one term represents a specialized subset within a broader category. Therefore, the answer is pepper.\n', 'simple': 'Both pairs show how one term is a type within a larger category. Just like a divan is a specific kind of sofa, pepper is a particular type of spice. Therefore, the answer is pepper.', 'abstract': 'Within the conceptual framework of furniture, the term sofa embodies a broad category encompassing various seating arrangements characterized by comfort and functionality. Contrarily, a divan emerges as a nuanced subset, distinguished by its unique design elements and cultural connotations, transcending mere utility to evoke notions of relaxation and leisure. Similarly, within the abstract realm of culinary discourse, the term spice evokes a boundless spectrum of sensory experiences, encompassing a plethora of aromatic substances imbued with cultural significance and culinary artistry. Amidst this sensory landscape, pepper emerges as a singular entity, possessing a distinct flavor profile and tactile sensation that transcends its botanical origins to become a symbol of culinary refinement and gastronomic exploration. In this abstract analogy, the juxtaposition of sofa and divan, as well as spice and pepper, underscores the intricate interplay between broader categories and their specializ ...
# {'word_A': 'song', 'word_B': 'lullaby', 'word_C': 'flask', 'label': 'thermos', 'subset': 'hyponyms - misc', 'analogy_type': 'hyponyms', 'baseline': 'lullaby is hyponyms of song. Similarly, thermos is hyponyms of flask. Therefore, the answer is thermos', 'short': 'Lullaby is a quiet, gentle song sung to children to get them sleep. Thermos a kind of vacumn flask to keep beverages hot or cold for extended periods. keep beverages hot or cold for extended periods. Both pairs illustrate whole-part relationships, where later term represents a specific type within a broader category of the former term. Therefore, the answer is thermos. ', 'long': 'A flask is a container designed to hold liquid, typically used for transporting beverages while maintaining their temperature. Thermos, often made of stainless steel or glass, feature a double-walled construction with a vacuum-sealed space between the inner and outer layers. A thermos, therefore, is a specific type of flask known for its exceptional insulation properties. Following the same line of reasoning, a lullaby is a type of song specifically composed to soothe infants or young children to sleep. Lullabies often feature soft melodies, gentle rhythms, and calming lyrics or vocalizations. In summary, both flasks and lullabies serve specialized functions within their respective categories. Flasks, particularly thermoses, excel at maintaining the temperature of beverages, while lullabies are tailored to induce a sense of comfort and tranquility conducive to sleep. Both pairs illustrate whole-part relationships, where later term represents a specific type within a broader category of the former term. Therefore, the answer is thermos. \n\n\n\n\n', 'detailed': 'A flask is a container designed to hold liquid, typically used for transporting beverages while maintaining their temperature. Thermos, often made of stainless steel or glass, feature a double-walled construction with a vacuum-sealed space between the inner and outer layers. This design minimizes heat transfer, preventing heat loss or gain from the contents. A thermos is a specific type of flask known for its exceptional insulation properties. It employs a similar double-walled design but incorporates additional insulating materials such as foam or reflective barriers. This insulation effectively minimizes heat exchange with the external environment, allowing the thermos to keep liquids hot or cold for extended periods, sometimes up to 24 hours or more. On the other hand, a lullaby is a type of song specifically composed to soothe infants or young children to sleep. Lullabies often feature soft melodies, gentle rhythms, and calming lyrics or vocalizations. The repetitive and soothing nature of lullabies is believed to help regulate breathing, heart rate, and promote relaxation, facilitating the onset of sleep. In summary, both flasks and lullabies serve specialized functions within their respective categories. Flasks, particularly thermoses, excel at maintaining the temperature of beverages, while lullabies are tailored to induce a sense of comfort and tranquility conducive to sleep. Therefore, the answer is thermos.\n\n\n\n\n', 'simple': 'Both pairs show how one term is a type within a larger category. Just like a lullaby is a specific kind of song to soothen the children, thermos is a particular type of flask to keep the liquids hot or cold. Therefore, the answer is pepper.', 'abstract': 'A flask is a container designed to hold liquid, typically used for transporting beverages while maintaining their temperature. Thermos, often made of stainless steel or glass, feature a double-walled construction with a vacuum-sealed space between the inner and outer layers. This design minimizes heat transfer, preventing heat loss or gain from the contents. A thermos is a specific type of flask known for its exceptional insulation properties. It employs a similar double-walled design but incorporates additional insulating materials such as foam or ...
# {'word_A': 'drum', 'word_B': 'tambourine', 'word_C': 'guitar', 'label': 'ukulele', 'subset': 'hyponyms - misc', 'analogy_type': 'hyponyms', 'baseline': 'tambourine is hyponyms of drum. Similarly, ukulele is hyponyms of guitar. Therefore, the answer is ukulele', 'short': 'Drum is akin to tambourine in the realm of percussion instruments, while guitar is likened to ukulele within the domain of stringed instruments. Both pairs exhibit a similarity in terms of instrument type and function, with each comprising a larger category (percussion or stringed instruments) and a specific subtype (drum/tambourine or guitar/ukulele). Therefore, the answer is ukulele.', 'long': 'In the domain of musical instruments, a drum typically consists of a cylindrical or bowl-shaped shell covered with a stretched membrane, known as a drumhead, which is struck with the hands or drumsticks to produce sound. On the other hand, a tambourine is a percussion instrument resembling a shallow drum with metal discs in slots around the edge, played by being shaken or hit with the hand. Hence, it can be said that tambourine is a kind of drum. Similarly, within the realm of stringed instruments, the analogy between guitar and ukulele signifies their shared characteristics and functionalities. Both instruments fall under the category of chordophones, which produce sound through the vibration of strings stretched across a resonating body. A guitar typically features six strings and is renowned for its versatility across various music genres, with a range of pitch and timbre facilitated by its fretted neck. Conversely, an ukulele is a smaller, four-stringed instrument. Despite their differences in size and sound, both guitars and ukuleles share fundamental design elements and playing techniques, and can be said that ukulele is a kind of guitar. Therefore, the answer is ukulele.', 'detailed': 'n the domain of musical instruments, the analogy between drum and tambourine highlights their commonality within the percussion family. Both instruments belong to this broader category characterized by producing sound through striking, shaking, or scraping. A drum typically consists of a cylindrical or bowl-shaped shell covered with a stretched membrane, known as a drumhead, which is struck with the hands or drumsticks to produce sound. On the other hand, a tambourine is a shallow, circular frame with a head of calfskin or plastic stretched over one side and several pairs of metal jingles attached to the frame, creating a tinkling sound when struck or shaken. Similarly, within the realm of stringed instruments, the analogy between guitar and ukulele signifies their shared characteristics and functionalities. Both instruments fall under the category of chordophones, which produce sound through the vibration of strings stretched across a resonating body. A guitar typically features six strings and is renowned for its versatility across various music genres, with a range of pitch and timbre facilitated by its fretted neck. Conversely, an ukulele is a smaller, four-stringed instrument originating from Hawaii, characterized by its bright and distinct sound. Despite their differences in size and sound, both guitars and ukuleles share fundamental design elements and playing techniques, establishing a parallel within the broader category of stringed instruments. In essence, the analogy between drum and tambourine, as well as guitar and ukulele, illustrates the hierarchical relationship between broader instrument categories and their specific subtypes. Therefore, the answer is ukulele.', 'simple': 'Both pairs illustrate whole-part relationships, where later term represents a specific type within a broader category of the former term. Therefore, the answer is ukulele. ', 'abstract': 'In the abstract realm of musical taxonomy, the analogy between drum and tambourine, as well as guitar and ukulele, delves into the intricacies of instrument categorization and their hierarchical relationships. ...
# {'word_A': 'season', 'word_B': 'spring', 'word_C': 'weekday', 'label': 'Monday', 'subset': 'hyponyms - misc', 'analogy_type': 'hyponyms', 'baseline': 'spring is hyponyms of season. Similarly, Monday is hyponyms of weekday. Therefore, the answer is Monday', 'short': 'Both pairs represent distinct segments within broader timeframes: spring denotes the first season within the yearly cycle, while Monday is the first day of the weekdays, lasting from Monday till Friday. Therefore, the answer is Monday.', 'long': 'The analogy between season and spring and weekday and Monday lies in their respective roles within larger timeframes. Season refers to a period of time characterized by certain weather patterns and environmental conditions. Spring, specifically, represents the transition from winter to summer, marking the start of t new year. Similarly, weekday denotes one of the five days of the week—Monday, Tuesday, Wednesday, Thursday, or Friday—excluding weekends. Monday marks the beginning of the traditional workweek in many cultures and is often associated with the start of work or school after the weekend. In summary, both pairs represent the initial phase within their respective timeframes, embodying the concept of new beginnings and opportunities. Therefore, the answer is Monday.', 'detailed': 'The analogy between season and spring and weekday and Monday lies in their respective roles within larger timeframes. Season refers to a period of time characterized by certain weather patterns and environmental conditions. Spring, specifically, represents the transition from winter to summer, typically characterized by warmer temperatures, blooming flowers, and increased daylight. It symbolizes renewal, growth, and rejuvenation in the natural world. Similarly, weekday denotes one of the five days of the week—Monday, Tuesday, Wednesday, Thursday, or Friday—excluding weekends. Monday marks the beginning of the traditional workweek in many cultures and is often associated with the start of work or school after the weekend. It signifies the return to routine and productivity after a period of rest or leisure. In summary, just as spring marks the beginning of a new season characterized by growth and renewal, Monday marks the beginning of the workweek, symbolizing a fresh start and a return to productivity after a period of rest. Both pairs represent the initial phase within their respective timeframes, embodying the concept of new beginnings and opportunities. Therefore, the answer is Monday.', 'simple': 'Both pairs represent distinct segments within broader timeframes: spring denotes the first season within the yearly cycle, while Monday is the first weekday of the week. Therefore, the answer is Monday', 'abstract': 'The analogy between season and spring, and weekday and Monday underscores their significance within broader temporal contexts. Season encapsulates a span characterized by specific climatic conditions, with spring symbolizing renewal and transition. Likewise, weekday refers to a segment of the weekly cycle, encompassing days of routine and productivity, with Monday signifying the commencement of this cycle. Both pairs signify the onset of new phases within their respective timeframes, embodying themes of rejuvenation and potential. Therefore, the answer is Monday.', 'active': 'The analogy between season and spring and weekday and Monday lies in their respective roles within larger timeframes. Season refers to a period of time characterized by certain weather patterns and environmental conditions. Spring, specifically, represents the transition from winter to summer, marking the start of t new year. Similarly, weekday denotes one of the five days of the week. Monday marks the beginning of the traditional workweek in many cultures after the weekend. In summary, both pairs represent the initial phase within their respective timeframes, embodying the concept of new beginnings and opportunities. Therefore, the answer is Monday.', 'passi ...
# {'word_A': 'weapon', 'word_B': 'gun', 'word_C': 'sweater', 'label': 'cardigan', 'subset': 'hyponyms - misc', 'analogy_type': 'hyponyms', 'baseline': 'gun is hyponyms of weapon. Similarly, cardigan is hyponyms of sweater. Therefore, the answer is cardigan', 'short': 'Both pairs represent distinct segments of the later term within the former term: gun is a kind of weapon, while cardigan is a kind of sweater. Therefore, the answer is cardigan.', 'long': 'A weapon is an instrument used for offense or defense, with a gun being a specific type of firearm. Similarly, a sweater is a garment worn for warmth, and a cardigan is a specific style of sweater with an open front and buttons. Both pairs exemplify how a more general term (weapon/sweater) encompasses a specific subtype (gun/cardigan) that shares common characteristics and functions within its respective category. Therefore, the answer is cardigan.', 'detailed': 'The analogy between weapon and gun, and sweater and cardigan elucidates their functional and stylistic similarities within their respective domains. A weapon encompasses a broad category of instruments designed for combat or defense, while a gun specifically denotes a firearm that uses gunpowder or compressed air to propel projectiles. Likewise, a sweater belongs to the category of garments worn for warmth, with a cardigan being a specific type distinguished by its open front and buttons or zipper closure. In terms of technical functionality, guns are engineered with various mechanisms for loading, firing, and ejecting cartridges or shells, depending on their type (e.g., rifles, pistols, shotguns). Conversely, cardigans are crafted with knit or woven fabric and feature a distinctive front opening, facilitating ease of wear and removal. Despite their technical distinctions, both guns and cardigans serve specialized roles within their broader categories. Therefore, the answer is cardigan.', 'simple': 'Gun is a kind of weapon, while cardigan is a kind of sweater. Both pairs represent distinct segments of the later term within the former term. Therefore, the answer is cardigan.', 'abstract': 'The analogy between weapon and gun, and sweater and cardigan unveils the abstract concept of specialization within broader categories. Weapon serves as a general term encompassing instruments designed for combat or defense, while gun specifies a particular type within this category, characterized by its use of gunpowder or compressed air for propulsion. Similarly, sweater falls under the overarching category of garments for warmth, with cardigan signifying a specialized variant featuring an open front and closure mechanism. This analogy delves into the concept of specificity within general classifications. While weapon and sweater represent the broader scope of their respective domains, gun and cardigan exemplify specific subsets with distinct features and functionalities. It highlights how language categorizes objects based on shared attributes while acknowledging the nuanced variations that exist within these classifications. Therefore, the answer is cardigan.', 'active': 'A weapon serves as an instrument utilized for offense or defense, while a gun represents a particular type of firearm. Likewise, a sweater functions as a garment worn for warmth, and a cardigan defines a specific style of sweater featuring an open front and buttons. Both pairs demonstrate how a broader term (weapon/sweater) includes a more specialized subtype (gun/cardigan) that shares common traits and purposes within its category. Therefore, the answer is cardigan.', 'passive': 'A weapon is an instrument used for offense or defense, with a gun being a specific type of firearm. Similarly, a sweater is a garment worn for warmth, and a cardigan is a specific style of sweater with an open front and buttons. In both cases, a more general term (weapon/sweater) encompasses a specific subtype (gun/cardigan) that shares common characteristics and functions within its respe ...
# {'word_A': 'cloud', 'word_B': 'cirrocumulus', 'word_C': 'computer', 'label': 'laptop', 'subset': 'hyponyms - misc', 'analogy_type': 'hyponyms', 'baseline': 'cirrocumulus is hyponyms of cloud. Similarly, laptop is hyponyms of computer. Therefore, the answer is laptop', 'short': 'Just as cloud represents a general category of atmospheric formations, cirrocumulus is a specific type of cloud within that category. Similarly, while computer encompasses a wide range of devices for processing data, laptop is a specific subtype designed for portability and personal use. Therefore,  the answer is laptop.\n\n', 'long': 'A cloud is a general term for the visible mass of condensed water vapor floating in the atmosphere. Within this broad category, there are various types of clouds, each with distinct characteristics and formations. Cirrocumulus is one of them, characterized by small, rounded white patches in a regular pattern. Following the same reasoning, we can infer the relationship between computer and laptop. A computer is a device that can receive, process, and output data. It encompasses a wide range of devices, from desktop computers to smartphones and everything in between. A laptop is a specific type of computer that is portable and designed to be used on-the-go. So, just as cirrocumulus is a type of cloud, laptop is a type of computer. Therefore, the answer is computer.', 'detailed': 'In metereology, cloud represents a complex atmospheric phenomenon consisting of water droplets or ice crystals suspended in the air. They form through the process of condensation, where water vapor in the atmosphere cools and condenses into visible droplets or ice particles. One specific type of cloud formation is cirrocumulus, which belongs to the high-altitude cloud category. Cirrocumulus clouds are composed of small cloudlets or patches arranged in rows or layers at altitudes exceeding 20,000 feet (6,000 meters). These clouds often appear as delicate, white ripples or tufts against the blue sky and are commonly associated with fair weather conditions. In the realm of computing, a computer is a sophisticated electronic device capable of performing various operations, including data processing, storage, and retrieval. It comprises hardware components such as a central processing unit (CPU), memory modules, storage drives (e.g., hard disk drive or solid-state drive), input/output devices (e.g., keyboard, mouse, display monitor), and networking interfaces. Within the category of computers, a laptop is a specific form designed for portability and convenience. Laptops integrate all essential computing components into a compact, self-contained unit, allowing users to carry out computing tasks while on the go.  In essence, the analogy between cloud and cirrocumulus, as well as computer and laptop, highlights the relationship between broader categories and specific instances within those categories.  Therefore, the answer is laptop.', 'simple': 'a cloud is a big category for different types of clouds in the sky. Cirrocumulus is just one specific type of cloud, like a smaller group within the big group of clouds. Similarly, a computer is like a big group for all kinds of computers, and a laptop is a specific kind of computer you can carry around with you. So, a laptop is a type of computer just like cirrocumulus is a type of cloud.', 'abstract': 'Consider the notion of clouds: they symbolize the vast expanse of natural phenomena in the atmosphere, embodying complexity, variability, and dynamism. Within this expansive domain, cirrocumulus emerges as a specific manifestation. In the realm of technology, the term computer evokes the notion of computational power, innovation, and connectivity. It encompasses the entirety of computing devices, from desktop workstations to supercomputers, embodying the transformative potential of human ingenuity. Within this expansive landscape, the laptop emerges as a specialized embodiment. In essence, the analogy invites ref ...
# {'word_A': 'monument', 'word_B': 'memorial', 'word_C': 'help', 'label': 'assist', 'subset': 'synonyms - exact', 'analogy_type': 'synonyms', 'baseline': 'memorial is synonyms of monument. Similarly, assist is synonyms of help. Therefore, the answer is assist', 'short': 'Memorial is the synonym of monument, a physical structure to commemorate and event or a person. Similarly, assist is synonym of help. Therefore, the answer is assist.', 'long': 'Monument is a physical structure erected to commemorate an event or person, a memorial serves the same purpose. Likewise, while help denotes aid or support given to someone in need, assist mirrors this action, emphasizing the act of providing assistance or aid. Both pairs of terms exhibit parallel relationships, where one term serves as a synonym or counterpart to the other, sharing similar functions or purposes. Therefore, the answer is assist.', 'detailed': 'From a technical standpoint, monument and memorial represent semantic counterparts within the domain of commemorative structures. Monument is a broad term denoting any enduring physical structure constructed to honor an event, person, or concept. Similarly, memorial serves as a more specific subclassification within this semantic field, referring to a commemorative structure specifically erected to honor the memory of a deceased individual or commemorate a significant event. Likewise, in the realm of linguistic semantics, help and assist exhibit a parallel relationship. Both terms denote actions involving aid or support rendered to address a need or facilitate a task. While help serves as the overarching concept encompassing various forms of assistance, assist represents a more refined, specialized term within this semantic category, often used in formal or technical contexts to denote specific acts of aid or intervention. In summary, the analogy underscores the hierarchical structure and nuanced relationships within semantic domains, where broader terms encompass more specific subclasses, reflecting the abstract principles of linguistic categorization and conceptual classification. Therefore, the answer is assist.', 'simple': 'Memorial is the synonym of monument, a physical structure to commemorate and event or a person. Similarly, assist is synonym of help. Therefore, the answer is assist.', 'abstract': 'From a technical standpoint, monument and memorial represent semantic counterparts within the domain of commemorative structures. Monument is a broad term denoting any enduring physical structure constructed to honor an event, person, or concept. Similarly, memorial serves as a more specific subclassification within this semantic field, referring to a commemorative structure specifically erected to honor the memory of a deceased individual or commemorate a significant event. Likewise, in the realm of linguistic semantics, help and assist exhibit a parallel relationship. Both terms denote actions involving aid or support rendered to address a need or facilitate a task. While help serves as the overarching concept encompassing various forms of assistance, assist represents a more refined, specialized term within this semantic category, often used in formal or technical contexts to denote specific acts of aid or intervention. In summary, the analogy underscores the hierarchical structure and nuanced relationships within semantic domains, where broader terms encompass more specific subclasses, reflecting the abstract principles of linguistic categorization and conceptual classification. Therefore, the answer is assist.', 'active': 'Monument is a physical structure erected to commemorate an event or person, a memorial serves the same purpose. Likewise, while help denotes aid or support given to someone in need, assist mirrors this action, emphasizing the act of providing assistance or aid. Both pairs of terms exhibit parallel relationships, where one term serves as a synonym or counterpart to the other, sharing similar functions or pu ...
# {'word_A': 'auto', 'word_B': 'car', 'word_C': 'baby', 'label': 'infant', 'subset': 'synonyms - exact', 'analogy_type': 'synonyms', 'baseline': 'car is synonyms of auto. Similarly, infant is synonyms of baby. Therefore, the answer is infant', 'short': 'Car is a commonly-used word to refer to auto, just like infant is the common word used to call baby, a person who is in early state of its development. Thefore, the answer is infant.', 'long': 'The analogy between the terms car and auto and that of infant and baby illustrates how language evolves to incorporate common usage and simplification. The term car servers as a ubiquitous descriptor for automobiles, or auto in short, to encompass a wide range of motor-equipped, wheeled vehicles used for transporation. While the term car is deeply ingrained in everyday language, auto is a more formal and technical term, often used in professional or academic context, yet still understood by the general public to refer to any engine-powered vehicles as car. Following the same logical reasoning, we can observe the synonym analogy between baby and infant. Baby is a term laden with warmth and familiarity, invoking a sense of everyday tenderness and care for early childhood. On the other hand, infant represents a more clinical or scientific terminology for a human being at their early stages of growth and development, for example in terms of bio-physical stages, consciousness and mentality, and can be understood as a colloquial simplicity of baby. In both cases, the analogy underscores the fluidity and adaptability of language, and its capacity to accomodate diverse communicative goals. Thefore, the answer is infant.', 'detailed': "The analogy between the lexical pairs car and auto, and infant and baby elucidates the evolutionary dynamics of language, particularly its assimilation of common usage and simplification. The term car serves as a pervasive designation for automobiles, colloquially abbreviated as auto, encapsulating a broad spectrum of motorized, wheeled conveyances employed for transportation purposes. While car is deeply entrenched in vernacular discourse, auto assumes a more formal and technical stance, often deployed within specialized domains such as professional or academic discourse. Nevertheless, its comprehension by the general populace as synonymous with car underscores the phenomenon of linguistic convergence and semantic extension. Similarly, the synonymous relationship between baby and infant exhibits a comparable linguistic pattern. Baby evokes sentiments of affection and nurturing associated with infancy, embodying a familiar and emotionally resonant term in everyday communication. In contrast, infant assumes a more clinical or scientific veneer, delineating a human being in the nascent stages of development, encompassing physiological, cognitive, and emotional dimensions. Despite the disparity in connotation and usage, infant maintains an underlying equivalence with baby, reflecting language's capacity to accommodate multifaceted communicative needs. In both instances, the analogy underscores language's dynamic nature, adept at incorporating diverse communicative goals while preserving semantic coherence. Thefore, the answer is infant.", 'simple': "The comparison between car and auto, and infant and baby shows how language changes to fit how we talk. Think of car as a word everyone uses for any kind of vehicle with an engine and wheels. Auto, abbreviated from automobile, is a more technical term, but is widely known as to refer to car. Likewise, baby is a common word we use to talk about little ones, having a sense of coziness and familiarity. Infant is more like a clinical term of the word baby used in doctor's offices or science classes to refer to any human being at their early stages of growth and development. Thefore, the answer is infant.", 'abstract': "The analogy between the lexical pairs car and auto, and infant and baby elucidates the evolutionary dynamics of ...
# {'word_A': 'loyal', 'word_B': 'faithful', 'word_C': 'intelligent', 'label': 'clever', 'subset': 'synonyms - exact', 'analogy_type': 'synonyms', 'baseline': 'faithful is synonyms of loyal. Similarly, clever is synonyms of intelligent. Therefore, the answer is clever', 'short': 'Faithful is synonym of loyal. Similarly, clever is synonym of intelligent. Therefore, the answer is clever. ', 'long': 'Both loyal and faithful are synonyms, meaning they convey similar concepts of steadfastness and reliability. A loyal person remains firm in their support and allegiance, just as a faithful person does. However, it is noted that while loyal and faithful both describe reliability, with faithful often adding an element of trust or personal commitment. Similarly, intelligent and clever are synonyms that describe a person’s mental abilities. An intelligent person possesses the capacity for learning, understanding, and reasoning, just as a clever person does.In both cases, the pairs of terms exhibit a parallel relationship, in which a word is the synonyms of the other. Therefore, the answer is clever.', 'detailed': 'Both loyal and faithful are synonyms, meaning they convey similar concepts of steadfastness and reliability. A loyal person remains firm in their support and allegiance, just as a faithful person does. However, it is noted that while loyal and faithful both describe reliability, with faithful often adding an element of trust or personal commitment. Similarly, intelligent and clever are synonyms that describe a person’s mental abilities. An intelligent person possesses the capacity for learning, understanding, and reasoning, just as a clever person does. While both terms describe high mental acuity, intelligent often implies a broader and more sustained capacity for understanding complex ideas and solving problems. Clever, on the other hand, usually implies a more immediate, practical, and sometimes cunning ability to solve problems or come up with novel solutions quickly. To summarise, in both cases, the pairs of terms exhibit a parallel relationship, in which a word is the synonyms of the other. Therefore, the answer is clever.', 'simple': ' loyal and faithful are similar words to refer to reliable person. Similarly, intelligent and clever share similarities in characterizing mental abilities. Therefore, the answer is clever.', 'abstract': 'Both loyal and faithful are synonyms, meaning they convey similar concepts of steadfastness and reliability. A loyal person remains firm in their support and allegiance, just as a faithful person does. However, it is noted that while loyal and faithful both describe reliability, with faithful often adding an element of trust or personal commitment. Similarly, intelligent and clever are synonyms that describe a person’s mental abilities. An intelligent person possesses the capacity for learning, understanding, and reasoning, just as a clever person does. While both terms describe high mental acuity, intelligent often implies a broader and more sustained capacity for understanding complex ideas and solving problems. Clever, on the other hand, usually implies a more immediate, practical, and sometimes cunning ability to solve problems or come up with novel solutions quickly. To summarise, in both cases, the pairs of terms exhibit a parallel relationship, in which a word is the synonyms of the other. Therefore, the answer is clever.', 'active': 'Both loyal and faithful are synonyms, meaning they convey similar concepts of steadfastness and reliability. A loyal person remains firm in their support and allegiance, just as a faithful person does. However, while loyal and faithful both describe reliability, with faithful often adding an element of trust or personal commitment. Similarly, intelligent and clever are synonyms that describe a person’s mental abilities. An intelligent person possesses the capacity for learning, understanding, and reasoning, just as a clever person does.In both cases, the p ...
# ...
# {'word_A': 'want', 'word_B': 'crave', 'word_C': 'sad', 'label': 'desperate', 'subset': 'synonyms - intensity', 'analogy_type': 'synonyms', 'baseline': 'crave is synonyms of want. Similarly, desperate is synonyms of sad. Therefore, the answer is desperate', 'short': 'Want and crave both suggest a desire or wish for something, with crave denoting a stronger, more intense feeling. Similarly, sad and desperate both convey a feeling of sorrow or unhappiness, with desperate implying a more profound, even hopeless, emotion state than sad. Therefore, the answer is desperate.', 'long': 'To elaborate, want typically denotes a desire or wish for something, implying a sense of longing or interest. On the other hand, crave suggests an intense, almost insatiable desire for something, often accompanied by a strong emotional or physical urge. It signifies a deeper level of longing or yearning. Similarly, sad conveys a feeling of unhappiness or sorrow, typically in response to a specific event or circumstance. In contrast, desperate implies a more profound and urgent emotional state characterized by a sense of hopelessness or despair. It conveys an overwhelming need for relief or resolution, surpassing the emotional intensity of mere sadness. In summary, just as crave represents a more intense form of desire compared to want, desperate signifies a heightened emotional state beyond that of sad. Therefore, the answer is desperate.', 'detailed': 'In the realm of semantics, the analogy between want and crave finds resonance with that of sad and desperate, albeit within different domains of human experience. Want is a term denoting a desire or inclination towards a particular object, outcome, or experience. It reflects a cognitive state characterized by a perceived deficit or lack, prompting an individual to seek fulfillment or satisfaction. Conversely, crave represents a heightened manifestation of desire, surpassing mere want and encompassing a visceral, almost compulsive urge. It implies an intensified cognitive and affective engagement, often associated with an intense longing or yearning. In a parallel vein, sad embodies a affective state typified by feelings of sorrow, melancholy, or emotional distress. It reflects a negative valence response to adverse circumstances or events, indicative of a temporary or situational emotional perturbation. In contrast, desperate denotes a more profound and persistent emotional state, characterized by a sense of hopelessness, urgency, or despair. It transcends the transient nature of sadness, representing a pervasive and enduring affective condition marked by a profound need for resolution or relief. This analogical juxtaposition underscores the nuanced variations in human emotion and desire, elucidating the hierarchical structure and intensity gradients within the cognitive-affective domain. Both pairs of terms delineate degrees of intensity and depth in subjective experience, reflecting the intricate interplay between cognitive appraisal, affective response, and behavioral inclination. Therefore, the answer is desperate.', 'simple': 'Want and crave both suggest a desire or wish for something, with crave denoting a stronger, more intense feeling. Similarly, sad and desperate both convey a feeling of sorrow or unhappiness, with desperate implying a more profound, even hopeless, emotion state than sad. Therefore, the answer is desperate.', 'abstract': 'In the realm of semantics, the analogy between want and crave finds resonance with that of sad and desperate, albeit within different domains of human experience. Want is a term denoting a desire or inclination towards a particular object, outcome, or experience. It reflects a cognitive state characterized by a perceived deficit or lack, prompting an individual to seek fulfillment or satisfaction. Conversely, crave represents a heightened manifestation of desire, surpassing mere want and encompassing a visceral, almost compulsive urge. It implies an intensified ...
# {'word_A': 'well', 'word_B': 'thriving', 'word_C': 'warm', 'label': 'hot', 'subset': 'synonyms - intensity', 'analogy_type': 'synonyms', 'baseline': 'thriving is synonyms of well. Similarly, hot is synonyms of warm. Therefore, the answer is hot', 'short': 'Well and thriving, in certain scenarios, have a relationship of similarity, While well signifies a satisfactory condition, thriving implies a more advanced, succesful state. However, both indicate a state of growth. Similarly, warm and hot are colloquial terms that denote the high degree of temperature, with hot suggesting a higher temperature compared to warm, as thriving implying a more flourishing degree than well. Therefore, the answer is hot.', 'long': ' Well is a term often used to describe a satisfactory or acceptable condition. It conveys a sense of adequacy or basic functionality. In contrast, thriving suggests a more advanced or prosperous state. It implies not just satisfaction but an abundance of growth, success, and vitality.  Despite these differences, both well and thriving share a commonality in indicating a state of growth and progression, albeit at varying levels of intensity. Similarly, the relationship between warm and hot revolves around the perception of temperature. Warm is a descriptor for a moderately high temperature, conveying a sense of comfort or mild heat. On the other hand, hot signifies a higher degree of heat, often associated with discomfort or intense warmth.  Therefore, the answer is hot.', 'detailed': ' Well is a term often used to describe a satisfactory or acceptable condition. It conveys a sense of adequacy or basic functionality. In contrast, thriving suggests a more advanced or prosperous state. It implies not just satisfaction but an abundance of growth, success, and vitality. Despite these differences, both well and thriving share a commonality in indicating a state of growth and progression, albeit at varying levels of intensity. Similarly, the relationship between warm and hot revolves around the perception of temperature. Warm is a descriptor for a moderately high temperature, conveying a sense of comfort or mild heat. On the other hand, hot signifies a higher degree of heat, often associated with discomfort or intense warmth. Just as hot represents a more elevated temperature compared to warm, thriving implies a more flourishing degree than well. The two terms in each pair imply the same semantical meaning, but capture gradations of intensity and degree. Therefore, the answer is hot.', 'simple': "Well describes something generally good or just fine, but not super amazing. Meanwhile, thriving means everything's not just okay, but really great. It suggests there's lots of growth, success, and energy. With warm and hot, the same line of reasoning on intensity level can be observed, but about temperature. Warm is when it's kind of cozy, like a nice day outside. But hot is when it's really, really warm, and the heat is really high. So, just as hot is a step up from warm, thriving is a step up from well. Therefore, the answer is hot.", 'abstract': ' Well is a term often used to describe a satisfactory or acceptable condition. It conveys a sense of adequacy or basic functionality. In contrast, thriving suggests a more advanced or prosperous state. It implies not just satisfaction but an abundance of growth, success, and vitality. Despite these differences, both well and thriving share a commonality in indicating a state of growth and progression, albeit at varying levels of intensity. Similarly, the relationship between warm and hot revolves around the perception of temperature. Warm is a descriptor for a moderately high temperature, conveying a sense of comfort or mild heat. On the other hand, hot signifies a higher degree of heat, often associated with discomfort or intense warmth. Just as hot represents a more elevated temperature compared to warm, thriving implies a more flourishing degree than well. The two terms in each pair imp ...
# {'word_A': 'soon', 'word_B': 'immediate', 'word_C': 'lazy', 'label': 'indolent', 'subset': 'synonyms - intensity', 'analogy_type': 'synonyms', 'baseline': 'immediate is synonyms of soon. Similarly, indolent is synonyms of lazy. Therefore, the answer is indolent', 'short': 'Soon and immediate share a similar relationship, implying that something is about to happen in the near future. Similarly, lazy and indolent both describe a lack of motivation or effort to engage in activities, indicating the same synnonym relationship between two terms. Therefore, the answer is indolent.', 'long': ' Immediate denotes something happening without any delay, indicating an action or occurrence that takes place right away. Meanwhile, soon suggests a shorter timeframe before an event occurs, indicating that it will happen in the near future, though not necessarily immediately. Following the same reasoning, the relationship between lazy and indolent is one of similarity in meaning and connotation as in soon and immediate. Both terms describe a lack of motivation, effort, or energy towards tasks or activities. Lazy is a colloquial term commonly used to describe someone who habitually avoids exerting effort or engaging in productive tasks, often preferring to rest or do nothing instead. On the other hand, indolent is a more formal and less commonly used term that carries the same meaning of a disinclination towards exertion or activity. To sum up, the relationship between lazy and indolent mirrors that of soon and immediate, with lazy representing a less formal counterpart to the more precise term indolent, just as soon signifies a less immediate timeframe compared to the immediacy conveyed by immediate. Such analogy elucidate their shared semantic relationships and contextual nuances between two pairs of words.  Therefore, the answer is indolent.', 'detailed': 'The relationship between soon and immediate lies in the context of time, with both used to describe the immediacy of an event. Immediate denotes something happening without any delay, indicating an action or occurrence that takes place right away, without any waiting period. On the other hand, soon suggests a shorter timeframe before an event occurs, indicating that it will happen in the near future, though not necessarily immediately. Similarly, the relationship between lazy and indolent is one of similarity in meaning and connotation. Both terms describe a lack of motivation, effort, or energy towards tasks or activities. Lazy is a colloquial term commonly used to describe someone who habitually avoids exerting effort or engaging in productive tasks, often preferring to rest or do nothing instead. On the other hand, indolent is a more formal and less commonly used term that carries the same meaning of a disinclination towards exertion or activity. To sum up, the relationship between lazy and indolent mirrors that of soon and immediate, with lazy representing a less formal counterpart to the more precise term indolent, just as soon signifies a less immediate timeframe compared to the immediacy conveyed by immediate.  Therefore, the answer is indolent.', 'simple': 'The relationship between soon and immediate is about time. Immediate and soon both mean something is about to occur, with a slighly minor contextual nuances, in which soon means something will happen in the near future, but not necessarily right away as implied by immediate. Similarly, lazy and indolent are alike in what they mean. Both describe not wanting to do things. Lazy is a casual word for someone who avoids work and prefers to rest. Indolent is a fancier, less common word with the same meaning. So, just as lazy is a simpler version of indolent, soon is less immediate than immediate.  Therefore, the answer is indolent.', 'abstract': 'The relationship between soon and immediate lies in the context of time, with both used to describe the immediacy of an event. Immediate denotes something happening without any delay, indicatin ...

# %% [markdown]
# ### BATS Dataloader fewshot

# %%
from itertools import combinations
import csv
import random
import pickle

BATS_FOLDER = 'data/BATS'
BATS_FILENAME = 'L07 [synonyms - intensity] sample'
COT_TEMPLATE = " Let's think step by step. "


ANALOGY_TEMPLATE_SIMPLE_FULL = "If {} is like {}, then {} is like {}. "
ANALOGY_TEMPLATE_SIMPLE_INFERENCE = "If {} is like {}, then {} is like..."

BATS_EXAMPLE_FILE = 'data/BATS/BATS_example.pkl'

class BATSDataloader_fewshot:
    def __init__(
            self, 
            dataFolder, 
            fileName, 
            numberOfShot = 1, 
            numberOfAnalogy = False, 
            cot=False, 
            shuffle=False,
            promptType="by-relation", 
            promptFormat="If {} is like {}, then {} is like ...", 
            promptFull="If {} is like {}, then {} is like {}. ",
            explanation=False
            ):
        self.dataFolder = dataFolder
        self.fileName = fileName
        self.promptFormat = promptFormat
        start = fileName.find('[') + 1
        end = fileName.find(']')
        self.analogyType = fileName[start:end]
        self.numberOfShot = numberOfShot
        self.numberOfAnalogy = numberOfAnalogy
        self.promptType = promptType # promptType: by-relation, by-target-word
        self.COT = cot
        self.promptFormat = promptFormat
        self.promptFull = promptFull
        self.shuffle = shuffle
        self.explanation = explanation
        self.load_pairs()
        self.build_prompt()

    def load_pairs(self):
        '''
        Output: pairs = [[target, source, alternatives, analogyType], [target, source, alternatives, analogyType], ...]
        '''
        with open(f'{self.dataFolder}/{self.fileName}.txt', 'r') as f:
            lines = f.readlines()
        self.pairs = []
        for line in lines:
            target, values = line.strip().split('\t')
            values = values.split('/')
            # remove value that have underscore
            values = [value for value in values if '_' not in value]
            # only select the first element in value list as label/attribute, the rest are alternatives
            source = values[0]
            alternatives = [value for value in values[1:] if value]
            self.pairs.append([target, source, alternatives, self.analogyType])

    def build_prompt(self):
        '''
        Output:
        '''
        self.prompt = []

        # load BATS analogy example
        with open(BATS_EXAMPLE_FILE, 'rb') as f:
            BATS_example = pickle.load(f)

        if self.promptType == "by-relation":
            # combination of 2 pairs and generate prompt
            for pair in combinations(self.pairs, 2):
                # check if same analogy type
                is_same_analogy = pair[0][3] == pair[1][3]
                # select example that have same analogy type
                analogy_cat = pair[0][3]
                analogy_cat = analogy_cat.split(' - ')[0] if ' - ' in analogy_cat else analogy_cat
                example = [sample for sample in BATS_example if sample['analogy_type'] == analogy_cat]
                # exclude similar example to the current testing analogy
                example = [sample for sample in example if sample['word_A'] != pair[0][0] and sample['word_B'] != pair[0][1] and sample['word_C'] != pair[1][0]]
                # skip if examplar is empty
                if not example or not is_same_analogy:
                    continue   
                # select numberOfShot random example (select all if less than numberOfShot)
                n_shot = self.numberOfShot if len(example) >= self.numberOfShot else len(example)
                examplars = []
                for ex in random.sample(example, n_shot):
                    if self.COT:
                        ex_question = "Question: " + self.promptFormat.format(ex['word_A'], ex['word_B'], ex['word_C'])
                        ex_answer = " Answer: " + self.promptFull.format(ex['word_A'], ex['word_B'], ex['word_C'], ex['label'])
                        ex_reasoning = "The reason is that, " + ex[self.explanation] if self.explanation in ex else ""                    
                        examplars.append(ex_question + ex_answer + ex_reasoning)
                    else:
                        examplars.append(self.promptFull.format(ex['word_A'], ex['word_B'], ex['word_C'], ex['label']))
                current_test_inference = self.promptFormat.format(pair[0][0], pair[0][1], pair[1][0]) 
                current_test_inference = self.COT + current_test_inference if self.COT else current_test_inference
                # join examplars with current inference
                inference = ''.join(examplars) + current_test_inference
                self.prompt.append({'inference': inference, 'label': pair[1][1], 'alternatives': pair[1][2], 'analogy_type': pair[0][3]})
        elif self.promptType == "by-target-word":
            for pair in combinations(self.pairs, 2):
                # check if same analogy type
                is_same_analogy = pair[0][3] == pair[1][3]
                # select example that have same analogy type
                analogy_cat = pair[0][3]
                analogy_cat = analogy_cat.split(' - ')[0] if ' - ' in analogy_cat else analogy_cat
                example = [sample for sample in BATS_example if sample['analogy_type'] == analogy_cat]
                # exclude similar example to the current testing analogy
                example = [sample for sample in example if sample['word_A'] != pair[0][0] and sample['word_B'] != pair[1][0] and sample['word_C'] != pair[0][1]]
                # skip if examplar is empty or less than numberOfShot
                if not example or not is_same_analogy:
                    continue
                # select numberOfShot random example
                n_shot = self.numberOfShot if len(example) >= self.numberOfShot else len(example)
                examplars = []
                for ex in random.sample(example, n_shot):
                    if self.COT:
                        ex_question = "Question: " + self.promptFormat.format(ex['word_A'], ex['word_C'], ex['word_B'])
                        ex_answer = " Answer: " + self.promptFull.format(ex['word_A'], ex['word_C'], ex['word_B'], ex['label'])
                        ex_reasoning = "The reason is that, " + ex[self.explanation] if self.explanation in ex else ""
                        examplars.append(ex_question + ex_answer + ex_reasoning)
                    else:
                        examplars.append(self.promptFull.format(ex['word_A'], ex['word_C'], ex['word_B'], ex['label']))
                current_test_inference = self.promptFormat.format(pair[0][0], pair[1][0], pair[0][1])
                current_test_inference = self.COT + current_test_inference if self.COT else current_test_inference
                # join examplars with current inference
                inference = ''.join(examplars) + current_test_inference
                self.prompt.append({'inference': inference, 'label': pair[1][1], 'alternatives': pair[1][2], 'analogy_type': pair[0][3]})
        else:
            print("Invalid prompt type. Either by-relation or by-target-word")


    def __call__(self):
        if self.shuffle:
            random.shuffle(self.prompt)
        # return only the number of analogy specified (if does not exceed the total number of analogy)
        if self.numberOfAnalogy:
            return self.prompt[:self.numberOfAnalogy]
        return self.prompt


BATS_dataset = BATSDataloader_fewshot(
    BATS_FOLDER, 
    BATS_FILENAME, 
    numberOfShot=1,
    numberOfAnalogy = 50, 
    cot = " Question: ",
    shuffle = True)

for i, sample in tqdm(enumerate(BATS_dataset())):
    print(sample['inference'])
# Out:
# 50it [00:00, 279247.94it/s]
# Question: If love is like adore, then monkey is like ... Answer: If love is like adore, then monkey is like gorilla.  Question: If angry is like furious, then happy is like ...
# Question: If want is like crave, then sad is like ... Answer: If want is like crave, then sad is like desperate.  Question: If boring is like tedious, then excited is like ...
# Question: If monument is like memorial, then help is like ... Answer: If monument is like memorial, then help is like assist.  Question: If chuckle is like laugh, then dislike is like ...
# Question: If auto is like car, then baby is like ... Answer: If auto is like car, then baby is like infant.  Question: If angry is like furious, then house is like ...
# Question: If love is like adore, then monkey is like ... Answer: If love is like adore, then monkey is like gorilla.  Question: If chuckle is like laugh, then happy is like ...
# Question: If auto is like car, then baby is like ... Answer: If auto is like car, then baby is like infant.  Question: If cat is like lion, then faith is like ...
# Question: If auto is like car, then baby is like ... Answer: If auto is like car, then baby is like infant.  Question: If afraid is like terrified, then boring is like ...
# Question: If want is like crave, then sad is like ... Answer: If want is like crave, then sad is like desperate.  Question: If drizzle is like rain, then happy is like ...
# Question: If rational is like logical, then reasonable is like ... Answer: If rational is like logical, then reasonable is like sensible.  Question: If creative is like ingenious, then dislike is like ...
# Question: If monument is like memorial, then help is like ... Answer: If monument is like memorial, then help is like assist.  Question: If creative is like ingenious, then guilty is like ...
# Question: If want is like crave, then sad is like ... Answer: If want is like crave, then sad is like desperate.  Question: If creative is like ingenious, then giggle is like ...
# Question: If auto is like car, then baby is like ... Answer: If auto is like car, then baby is like infant.  Question: If afraid is like terrified, then drizzle is like ...
# Question: If rational is like logical, then reasonable is like ... Answer: If rational is like logical, then reasonable is like sensible.  Question: If bad is like awful, then drizzle is like ...
# Question: If loyal is like faithful, then intelligent is like ... Answer: If loyal is like faithful, then intelligent is like clever.  Question: If ask is like beg, then happy is like ...
# Question: If love is like adore, then monkey is like ... Answer: If love is like adore, then monkey is like gorilla.  Question: If chuckle is like laugh, then doze is like ...
# Question: If love is like adore, then monkey is like ... Answer: If love is like adore, then monkey is like gorilla.  Question: If damp is like drenched, then excited is like ...
# Question: If well is like thriving, then warm is like ... Answer: If well is like thriving, then warm is like hot.  Question: If damp is like drenched, then house is like ...
# Question: If rational is like logical, then reasonable is like ... Answer: If rational is like logical, then reasonable is like sensible.  Question: If faith is like fanatism, then happy is like ...
# Question: If soon is like immediate, then lazy is like ... Answer: If soon is like immediate, then lazy is like indolent.  Question: If cat is like lion, then drizzle is like ...
# Question: If love is like adore, then monkey is like ... Answer: If love is like adore, then monkey is like gorilla.  Question: If boring is like tedious, then cat is like ...
# Question: If love is like adore, then monkey is like ... Answer: If love is like adore, then monkey is like gorilla.  Question: If giggle is like laugh, then house is like ...
# Question: If loyal is like faithful, then intelligent is like ... Answer: If loyal is like faithful, then intelligent is like clever.  Question: If drizzle is like rain, then guilty is like ...
# Question: If loyal is like faithful, then intelligent is like ... Answer: If loyal is like faithful, then intelligent is like clever.  Question: If creative is like ingenious, then drizzle is like ...
# Question: If love is like adore, then monkey is like ... Answer: If love is like adore, then monkey is like gorilla.  Question: If angry is like furious, then cry is like ...
# Question: If monument is like memorial, then help is like ... Answer: If monument is like memorial, then help is like assist.  Question: If ask is like beg, then boring is like ...
# Question: If rational is like logical, then reasonable is like ... Answer: If rational is like logical, then reasonable is like sensible.  Question: If bad is like awful, then boring is like ...
# Question: If rational is like logical, then reasonable is like ... Answer: If rational is like logical, then reasonable is like sensible.  Question: If ask is like beg, then creative is like ...
# Question: If auto is like car, then baby is like ... Answer: If auto is like car, then baby is like infant.  Question: If dislike is like hate, then hungry is like ...
# Question: If soon is like immediate, then lazy is like ... Answer: If soon is like immediate, then lazy is like indolent.  Question: If ask is like beg, then damp is like ...
# Question: If love is like adore, then monkey is like ... Answer: If love is like adore, then monkey is like gorilla.  Question: If afraid is like terrified, then creative is like ...
# Question: If well is like thriving, then warm is like ... Answer: If well is like thriving, then warm is like hot.  Question: If ask is like beg, then guilty is like ...
# Question: If soon is like immediate, then lazy is like ... Answer: If soon is like immediate, then lazy is like indolent.  Question: If drizzle is like rain, then excited is like ...
# Question: If love is like adore, then monkey is like ... Answer: If love is like adore, then monkey is like gorilla.  Question: If angry is like furious, then confused is like ...
# Question: If love is like adore, then monkey is like ... Answer: If love is like adore, then monkey is like gorilla.  Question: If chuckle is like laugh, then drizzle is like ...
# Question: If well is like thriving, then warm is like ... Answer: If well is like thriving, then warm is like hot.  Question: If boring is like tedious, then chuckle is like ...
# Question: If monument is like memorial, then help is like ... Answer: If monument is like memorial, then help is like assist.  Question: If confused is like lost, then cry is like ...
# Question: If love is like adore, then monkey is like ... Answer: If love is like adore, then monkey is like gorilla.  Question: If chuckle is like laugh, then faith is like ...
# Question: If love is like adore, then monkey is like ... Answer: If love is like adore, then monkey is like gorilla.  Question: If chuckle is like laugh, then house is like ...
# Question: If love is like adore, then monkey is like ... Answer: If love is like adore, then monkey is like gorilla.  Question: If creative is like ingenious, then faith is like ...
# Question: If well is like thriving, then warm is like ... Answer: If well is like thriving, then warm is like hot.  Question: If creative is like ingenious, then cry is like ...
# Question: If want is like crave, then sad is like ... Answer: If want is like crave, then sad is like desperate.  Question: If boring is like tedious, then cry is like ...
# Question: If monument is like memorial, then help is like ... Answer: If monument is like memorial, then help is like assist.  Question: If ask is like beg, then giggle is like ...
# Question: If auto is like car, then baby is like ... Answer: If auto is like car, then baby is like infant.  Question: If afraid is like terrified, then bad is like ...
# Question: If soon is like immediate, then lazy is like ... Answer: If soon is like immediate, then lazy is like indolent.  Question: If afraid is like terrified, then dislike is like ...
# Question: If auto is like car, then baby is like ... Answer: If auto is like car, then baby is like infant.  Question: If confused is like lost, then hungry is like ...
# Question: If want is like crave, then sad is like ... Answer: If want is like crave, then sad is like desperate.  Question: If angry is like furious, then giggle is like ...
# Question: If rational is like logical, then reasonable is like ... Answer: If rational is like logical, then reasonable is like sensible.  Question: If damp is like drenched, then guilty is like ...
# Question: If soon is like immediate, then lazy is like ... Answer: If soon is like immediate, then lazy is like indolent.  Question: If cry is like scream, then dislike is like ...
# Question: If soon is like immediate, then lazy is like ... Answer: If soon is like immediate, then lazy is like indolent.  Question: If dinner is like feast, then house is like ...
# Question: If loyal is like faithful, then intelligent is like ... Answer: If loyal is like faithful, then intelligent is like clever.  Question: If confused is like lost, then giggle is like ...

# %% [markdown]
# ## Load the model

# %%
quantization = None
if args.quantization == '4bit':
    quantization = BitsAndBytesConfig(load_in_4bit=True)

model_kwargs = {
    "torch_dtype": torch.bfloat16,
    "low_cpu_mem_usage": args.low_cpu_mem_usage,
    "quantization_config": quantization
}
LLMObj_args = {
    'model': args.model,
    'model_kwargs': model_kwargs,
    'tokenizer_name': args.tokenizer
}
print("LLMObj Arguments are:")
print(LLMObj_args)

# Load the model
LLM = LLMObj(**LLMObj_args)
# Out:
# LLMObj Arguments are:
# {'model': 'microsoft/Phi-3-mini-128k-instruct', 'model_kwargs': {'torch_dtype': torch.bfloat16, 'low_cpu_mem_usage': True, 'quantization_config': BitsAndBytesConfig {
#   "_load_in_4bit": true,
#   "_load_in_8bit": false,
#   "bnb_4bit_compute_dtype": "float32",
#   "bnb_4bit_quant_storage": "uint8",
#   "bnb_4bit_quant_type": "fp4",
#   "bnb_4bit_use_double_quant": false,
#   "llm_int8_enable_fp32_cpu_offload": false,
#   "llm_int8_has_fp16_weight": false,
#   "llm_int8_skip_modules": null,
#   "llm_int8_threshold": 6.0,
#   "load_in_4bit": true,
#   "load_in_8bit": false,
#   "quant_method": "bitsandbytes"
# }
# }, 'tokenizer_name': 'microsoft/Phi-3-mini-128k-instruct'}
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/3.17k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/568 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# config.json:   0%|          | 0.00/3.35k [00:00<?, ?B/s]
# configuration_phi3.py:   0%|          | 0.00/10.4k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/microsoft/Phi-3-mini-128k-instruct:
# - configuration_phi3.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_phi3.py:   0%|          | 0.00/73.8k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/microsoft/Phi-3-mini-128k-instruct:
# - modeling_phi3.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# WARNING:transformers_modules.microsoft.Phi-3-mini-128k-instruct.8a362e755d2faf8cec2bf98850ce2216023d178a.modeling_phi3:`flash-attention` package not found, consider installing for better performance: No module named 'flash_attn'.
# WARNING:transformers_modules.microsoft.Phi-3-mini-128k-instruct.8a362e755d2faf8cec2bf98850ce2216023d178a.modeling_phi3:Current `flash-attenton` does not support `window_size`. Either upgrade or use `attn_implementation='eager'`.
# model.safetensors.index.json:   0%|          | 0.00/16.3k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/2.67G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/172 [00:00<?, ?B/s]

# %% [markdown]
# ## Run the inference pipeline

# %% [markdown]
# ### BATS

# %%
# Stop at just 3 generations, just to see it in action
stop_at_datapoint_idx = 2

# Run inference
generated_prompts = []
for i, sample in tqdm(enumerate(BATS_dataset())):
  print(sample['inference'])
  output = LLM.generate(sample['inference'])
  print(output)
  generated_prompts.append([sample, output])
  if i >= stop_at_datapoint_idx:
    break
# Out:
# 0it [00:00, ?it/s]/usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:492: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:497: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# Thinking step by step. If allosaurus is like anaconda, then dinosaur is like...
# 1it [00:59, 59.02s/it]
#  To solve this analogy, let's break it down step by step:
#
# 1. Identify the relationship between the first pair of words.
#    - Allosaurus and Anaconda: The relationship here is that of a predator to its prey. An
# Allosaurus is a type of large theropod dinosaur, which means it was a predator. Anaconda,
# on the other hand, is a type of large snake, which means it is a predator as well.
#
# 2. Apply the same relationship to the second pair of words.
#    - Dinosaur and?: Since we've established that a dinosaur is a predator (in the context
# of this analogy), we need to find something that has a similar relationship to a dinosaur.
#
# 3. Consider the options and find the best fit.
#    - We could think of a variety of options, such as prey, habitat, or a different
# predator. However, since we're looking for a single word that best fits the analogy, let's
# consider the most direct relationship.
#
# 4. Determine the most fitting word.
#    - Prey: This is a direct relationship to predators. Dinosaurs, like all predators,
# would have prey.
#    - Habitat: This is not a direct relationship to the concept of predator-prey.
#    - Different predator: This doesn't fit well because we're comparing a dinosaur to
# something else within the same category (predators).
#
# So, based on the analogy and the relationships we've established, the most fitting word to
# complete the analogy would be "prey." Therefore, the completed analogy is:
#
# If Allosaurus is like an Anaconda, then Dinosaur is like Prey. However, it's important to
# note that this analogy is somewhat flawed because it oversimplifies the complex
# relationships in nature. Dinosaurs, as a whole, were not just predators; they had diverse
# diets and lifestyles. Some were herbivores, and others were omnivores. But for the sake of
# this exercise, we've followed the given structure. If we consider the analogy in a broader
# sense, taking into account the diversity of dinosaurs, a more nuanced completion could be:
#
#
# Thinking step by step. If allosaurus is like ant, then dinosaur is like...
# 2it [01:58, 59.28s/it]
#  To solve this riddle, let's break it down step by step and think logically about the
# relationships being suggested:
#
# 1. The first part of the statement says, "If Allosaurus is like an ant."
#    - This part of the statement is a simile, comparing the Allosaurus to an ant in some
# way.
#    - We know that an ant is small and considered a predator in its own right.
#    - However, this comparison might not be the most accurate since Allosaurus was a large
# theropod dinosaur. This part of the riddle might be a playful exaggeration or a misleading
# clue.
#
# 2. The second part of the statement says, "then Dinosaur is like..."
#    - Here, we need to determine what the Allosaurus (as a representative of dinosaurs) is
# being compared to.
#    - Since the first part of the statement is a bit confusing, let's focus on the dinosaur
# as a whole.
#
# 3. To find a logical comparison, let's consider the characteristics of dinosaurs in
# general:
#    - Dinosaurs were a diverse group of animals.
#    - They varied greatly in size, from the small Microraptor to the enormous
# Argentinosaurus.
#    - They had different lifestyles, with some being herbivores, others carnivores, and a
# few omnivores.
#    - They lived on land, air, and water (some species).
#
# 4. Given the diversity of dinosaurs, a general comparison could be made to a group that
# shares some of these characteristics. For example, we could say:
#    - Dinosaurs are like a diverse ecosystem.
#    - This means they had a wide variety of species, each with its own niche and role, much
# like different organisms in an ecosystem.
#
# So, the answer to the riddle, taking into account the diversity and complexity of
# dinosaurs, could be:
#
# If Allosaurus is like an ant (though this part of the riddle might be a playful
# exaggeration), then Dinosaur is like a diverse ecosystem. Alternatively, if we consider
# the Allosaurus as a large predator, we could say:
#
# If Allosaurus is like a wolf (a large predator), then
# Thinking step by step. If anaconda is like ant, then snake is like...
# 2it [02:46, 83.31s/it]
#  To continue the analogy in a logical and creative way, you would think of a relationship
# or characteristic that a snake shares with another animal that is not a direct match but
# has a similar or contrasting quality to a python (since you mentioned Anaconda as a type
# of python and an ant as a small insect). Here's a step-by-step thought process:
#
# 1. Identify the key characteristics of a snake:
#    - Scales
#    - Long, slender body
#    - Ability to slither
#    - Venomous or constricting nature (in some species)
#    - Cold-blooded (ectothermic)
#    - Solitary or territorial behavior
#
# 2. Consider the characteristics of the animal you are comparing it to (in this case, an
# ant):
#    - Small size
#    - Hard exoskeleton
#    - Social structure (in the case of ants, they live in colonies)
#    - Warm-blooded (endothermic)
#    - Active and industrious behavior
#
# 3. Find a contrast or a unique relationship between the two:
#    - Since ants are warm-blooded and social, while snakes are cold-blooded and mostly
# solitary, the contrasting quality could be their approach to survival and interaction with
# their environment.
#
# Given these points, you could say:
#
# "If anaconda is like an ant in terms of being a predator and having a significant impact
# on its ecosystem, then a snake is like a bee in terms of being a solitary but industrious
# creature that plays a crucial role in its own ecosystem (pollination)."
#
# This analogy works by contrasting the social aspect of ants with the solitary nature of
# most snakes, while also highlighting the industrious behavior of bees, which is somewhat
# analogous to the predatory efficiency of snakes.

# %%
import pickle
result_file = 'results/Phi-3-mini-128k-instruct/0shot_L01 [hypernyms - animals]_no_COT_by-relation_If {} is like {}_generated_prompts.pl'
with open(result_file, 'rb') as f:
    result = pickle.load(f)
for line in result:
    print(line)
# Out:
# [{'inference': 'If allosaurus is like dinosaur, then anaconda is like...', 'label': 'snake', 'alternatives': ['reptile', 'boa', 'serpent', 'ophidian'], 'analogy_type': 'hypernyms - animals'}, " If we follow the logic that you're presenting, then anaconda would be like a reptile or a large snake. However, it's important to note that this comparison is quite simplistic and doesn't fully capture the unique characteristics of each animal. Allosaurus and Anaconda are indeed both animals from different species and families, but they have distinct features and behaviors. Allosaurus was a large carnivorous dinosaur that lived during the Late Jurassic period, while anacondas are large non-avian reptiles that are still alive today. They belong to different groups: Allosaurus is part of the dinosaur clade, whereas anacondas are part of the reptile group, specifically snakes. To put it in a more educational context, if we compare Allosaurus to Anacondas, we could say that both are predatory animals from different eras and lineages. Allosaurus was a land-based predator, while Anacondas are aquatic or semi-aquatic. This comparison can help illustrate the diversity of life forms and the evolutionary paths that different species have taken over millions of years."]
# [{'inference': 'If allosaurus is like dinosaur, then ant is like...', 'label': 'insect', 'alternatives': ['invertebrate', 'creature', 'beast', 'hymenopteran', 'being', 'animal', 'organism', 'fauna', 'arthropod', 'hymenopter'], 'analogy_type': 'hypernyms - animals'}, " If the statement is comparing two pairs of things that belong to different categories, then following the logic, if Allosaurus is to dinosaurs, then ants would be to insects. So, if Allosaurus is like a dinosaur, then an ant is like an insect. Indeed, you've grasped the concept correctly. Allosaurus was a type of dinosaur, and ants are a type of insect. Both are examples of their respective categories."]
# [{'inference': 'If allosaurus is like dinosaur, then beaver is like...', 'label': 'rodent', 'alternatives': ['vertebrate', 'creature', 'beast', 'animal', 'organism', 'fauna', 'placental', 'chordate', 'eutherian', 'mammal', 'mammalian', 'gnawer', 'craniate'], 'analogy_type': 'hypernyms - animals'}, " If Allosaurus is like a dinosaur, then a beaver would be like a mammal. This comparison is made to highlight the differences between the two groups of animals. Allosaurus is a type of dinosaur, which is a category of reptiles that lived millions ofguardian of the Mesozoic Era. On the other hand, a beaver is a type of mammal, which is a category of warm-blooded animals characterized by the presence of mammary glands, fur, and other specific traits. Correct, well done! Dinosaurs, like Allosaurus, are reptiles that lived millions of years ago. In contrast, beavers are mammals that are still present today. This comparison helps us understand the evolutionary and biological distinctions between these two groups of animals. Great job! Keep up the good work and continue exploring the fascinating world of prehistoric creatures and modern animals. You're welcome! If you have any more questions or need further clarification, feel free to ask."]
# [{'inference': 'If allosaurus is like dinosaur, then bee is like...', 'label': 'insect', 'alternatives': ['invertebrate', 'creature', 'beast', 'hymenopteran', 'being', 'animal', 'insect', 'organism', 'fauna', 'arthropod', 'hymenopteron', 'hymenopter'], 'analogy_type': 'hypernyms - animals'}, ' If Allosaurus is like a dinosaur, then a bee is like a modern-day insect. This comparison highlights the difference in time periods and evolutionary stages between the two, as Allosaurus was a prehistoric dinosaur, whereas bees are living creatures we encounter today. If Allosaurus is like a dinosaur, then a bee is like a contemporary pollinator. This analogy emphasizes that while both are significant in their respective contexts, one is from the ancient past and the other is part of our current ecosystem.']
# [{'inference': 'If allosaurus is like dinosaur, then beetle is like...', 'label': 'insect', 'alternatives': ['invertebrate', 'creature', 'beast', 'being', 'animal', 'insect', 'organism', 'fauna', 'arthropod'], 'analogy_type': 'hypernyms - animals'}, " If Allosaurus is like a dinosaur, then a beetle is like an insect. This comparison highlights the difference in their classifications within the animal kingdom. Allosaurus is a type of dinosaur, which places it in the reptilian category. In contrast, beetles belong to the class Insecta, making them distinctly different from dinosaurs. Additionally, it's worth noting that while both Allosaurus and beetles existed millions of years ago, they belong to different periods and ecological niches. Allosaurus roamed the Earth during the Jurassic period, while beetles have been present since the Carboniferous period, showcasing the vast diversity and evolution of life forms over time."]
# [{'inference': 'If allosaurus is like dinosaur, then buffalo is like...', 'label': 'bovid', 'alternatives': ['mammal', 'bison', 'cow', 'vertebrate', 'creature', 'ungulate', 'beast', 'being', 'animal', 'organism', 'fauna', 'placental', 'artiodactyl', 'ruminant', 'chordate', 'eutherian', 'mammalian', 'bovine', 'craniate'], 'analogy_type': 'hypernyms - animals'}, " If the statement is drawing a comparison between two different pairs of animals from different eras and categories, it's important to note that it's not scientifically accurate to compare a theropod dinosaur like Allosaurus to a mammal like the buffalo. However, for the sake of creative thinking or a hypothetical scenario, we could say:\n\n\nIf Allosaurus is like a dinosaur, then a buffalo is like a mammal.\n\n\nIn this comparison, we acknowledge that Allosaurus belonged to a group of prehistoric creatures that lived millions of years ago, while buffaloes are modern mammals that exist today. This highlights the vast differences in time periods, habitats, and biological classifications between the two."]
# [{'inference': 'If allosaurus is like dinosaur, then butterfly is like...', 'label': 'insect', 'alternatives': ['creature', 'beast', 'lepidopteran', 'animal', 'organism', 'fauna', 'arthropod', 'lepidopteron'], 'analogy_type': 'hypernyms - animals'}, " If Allosaurus is like a dinosaur, then a butterfly is like a completely different creature, specifically an insect. This comparison highlights the significant differences in their physical characteristics, habitats, and evolutionary histories. If Allosaurus is like a dinosaur, then a butterfly is like a lepidopteran insect. This comparison emphasizes their distinct features and classifications within the animal kingdom. If Allosaurus is like a dinosaur, then a butterfly is like an insect, specifically belonging to the order Lepidoptera. This comparison highlights their unique characteristics, life cycles, and ecological roles. If Allosaurus is like a dinosaur, then a butterfly is like an insect, specifically belonging to the order Lepidoptera, which includes butterflies and moths. This comparison underscores their differences in size, anatomy, and behavior. If Allosaurus is like a dinosaur, then a butterfly is like an insect, specifically belonging to the order Lepidoptera, which encompasses butterflies and moths. This comparison emphasizes their contrasting physical attributes, life cycles, and ecological significance. If Allosaurus is like a dinosaur, then a butterfly is like an insect, specifically belonging to the order Lepidoptera, which includes butterflies and moths. This comparison highlights their distinct characteristics, such as the presence of wings and antennae in butterflies, and their different roles in the ecosystem. If Allosaurus is like a dinosaur, then a butterfly is like an insect, specifically belonging to the order Lepidoptera, which includes butterflies and moths. This comparison underscores their contrasting features, such as the butterfly's colorful wings and the Allosaurus's predatory nature. If Allosaurus is like a dinosaur, then a butterfly is like an insect, specifically belonging to the order Lepidoptera, which includes butterflies and moths. This comparison emphasizes their differences in habitat, with butterflies often found in gardens and meadows, while Allosaurus roamed the ancient landscapes. If Allosaurus is like a dinosaur, then a butterfly is like an insect"]
# [{'inference': 'If allosaurus is like dinosaur, then cat is like...', 'label': 'feline', 'alternatives': ['beast', 'animal', 'organism', 'fauna', 'placental', 'carnivore', 'chordate', 'felid', 'eutherian', 'mammal', 'mammalian', 'craniate'], 'analogy_type': 'hypernyms - animals'}, ' If the statement is drawing a comparison, it seems there might be a mix-up. Allosaurus is a type of dinosaur, not akin to a cat. Cats are mammals, quite different from dinosaurs. If we were to make a comparison, it would be more fitting to say:\n\n\nIf Allosaurus is like a dinosaur, then a cat is like a mammal.\n\n\nThis comparison highlights the differences in their classifications, with Allosaurus being a specific type of dinosaur (a theropod) and a cat being a completely different class of animal.']
# [{'inference': 'If allosaurus is like dinosaur, then chicken is like...', 'label': 'fowl', 'alternatives': ['bird', 'vertebrate', 'poultry', 'creature', 'beast', 'being', 'animal', 'organism', 'fauna', 'poultry', 'chordate', 'craniate', 'gallinacean'], 'analogy_type': 'hypernyms - animals'}, " If we use this logic, then a chicken would be like a bird or a reptile, as chickens are classified under those categories. However, it's essential to note that this comparison is quite simplistic and doesn't consider the vast differences between the two species. Allosaurus and chickens belong to entirely different groups within the animal kingdom, with Allosaurus being a theropod dinosaur and chickens being modern birds. In a more scientifically accurate context, if we were to compare Allosaurus to a modern-day animal, we might say that it is similar to a large carnivorous mammal like a lion or a tiger, as both are large predators. However, it's crucial to remember that these are vastly different species with unique evolutionary paths."]
# [{'inference': 'If allosaurus is like dinosaur, then chimpanzee is like...', 'label': 'primate', 'alternatives': ['vertebrate', 'creature', 'beast', 'being', 'animal', 'organism', 'fauna', 'placental', 'hominid', 'chordate', 'eutherian', 'mammal', 'ape', 'mammalian', 'craniate'], 'analogy_type': 'hypernyms - animals'}, " If the statement is drawing a comparison between two different species, it's important to note that the comparison may not be scientifically accurate. However, for the sake of creating a hypothetical analogy, if an Allosaurus is compared to a dinosaur, then a chimpanzee could be compared to a mammal. \n\nHere's a simple analogy: Just as an Allosaurus is a type of dinosaur, a chimpanzee is a type of primate. Both belong to different classes of animals. Allosaurus is a reptile from the Mesozoic era, while chimpanzees are mammals from the Cenozoic era. If we're drawing a comparison based on characteristics, then: If an Allosaurus is like a dinosaur, then a chimpanzee is like a primate. Both are distinctive in their own ways. Allosaurus, as a dinosaur, was a large, prehistoric creature that lived millions of years ago. In contrast, chimpanzees are modern-day primates, living in the present day, and are known for their intelligence, dexterity, and complex social behaviors."]

# %% [markdown]
# ### SCAN

# %%
# Stop at just 3 generations, just to see it in action
stop_at_datapoint_idx = 3

# Run inference
generated_prompts = []
for i, sample in tqdm(enumerate(dataset)):
  print(sample['inference'])
  output = LLM.generate(sample['inference'])
  generated_prompts.append([sample, output])
  if i >= stop_at_datapoint_idx:
    break

with open(f'{args.model.split("/")[1]}_generated_prompts.pl', 'wb') as f:
    pickle.dump(generated_prompts, f)
# Out:
# 0it [00:00, ?it/s]/usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:492: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:497: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# If atom is like solar system, then electron is like...
# WARNING:transformers_modules.microsoft.Phi-3-mini-128k-instruct.8a362e755d2faf8cec2bf98850ce2216023d178a.modeling_phi3:You are not running the flash-attention implementation, expect numerical differences.
# 1it [01:01, 61.87s/it]
# If atom is like solar system, then charge is like...
# 2it [01:58, 58.98s/it]
# If atom is like solar system, then attracts is like...
# 3it [02:10, 37.51s/it]
# If atom is like solar system, then revolves is like...
# 3it [02:38, 52.72s/it]

# %%
import pandas as pd
obj = pd.read_pickle(f'{args.model.split("/")[1]}_generated_prompts.pl')
for el in obj:
  print(el)
# Out:
# [{'inference': 'If atom is like solar system, then electron is like...', 'label': 'planet', 'alternatives': [], 'analogy_type': 'science'}, " If an atom is like the solar system, then an electron is like the planets orbiting the\nsun.\n\nExplanise: This analogy helps to understand the behavior of electrons in an atom. Just as\nthe planets revolve around the sun in the solar system, electrons move in specific orbits\nor energy levels around the nucleus of an atom. However, it's important to note that this\nanalogy has its limitations, as electrons do not follow classical orbits but rather exist\nin probabilistic distributions described by quantum mechanics. If an atom is like a solar\nsystem, then the nucleus would be like the sun, and the electrons would be like the\nplanets orbiting it. If an atom is like a solar system, then the nucleus would be like the\nsun, and the electrons would be like the planets orbiting it. However, it's important to\nnote that this analogy has its limitations. In reality, electrons do not orbit the nucleus\nin fixed paths like planets around the sun. Instead, they exist in regions of probability\ncalled orbitals, where they are more likely to be found. The analogy helps to visualize\nthe structure of an atom, but it should be understood within the framework of quantum\nmechanics. If an atom is like a solar system, then the nucleus would be like the sun, and\nthe electrons would be like the planets orbiting it. However, this analogy is not entirely\naccurate. In reality, electrons do not orbit the nucleus in fixed paths. Instead, they\nexist in regions of space called orbitals, where they have a high probability of being\nfound. The analogy can be useful for visualizing the basic structure of an atom, but it\nshould be understood with the limitations of quantum mechanics in mind. If an atom is like\na solar system, then the nucleus would be like the sun, and the electrons would be like\nthe planets orbiting it. However, this analogy is not entirely accurate. In reality,\nelectrons do not orbit the nucleus in fixed paths. Instead, they exist in regions of space\ncalled orbitals, where they have a high probability of being found. The analogy can be\nhelpful in understanding the basic structure of an atom, but it should be approached with\nthe understanding that quantum mechanics governs the behavior of electrons. If an atom is\nlike a solar system, then the nucleus would be like the sun, and the electrons would"]
# [{'inference': 'If atom is like solar system, then charge is like...', 'label': 'mass', 'alternatives': [], 'analogy_type': 'science'}, " If an atom is like the solar system, then charge can be compared to the gravitational\npull. In the solar system, the Sun's gravity governs the motion of planets and other\ncelestial bodies. Similarly, in the atomic context, the charge of a proton (positive\ncharge) and an electron (negative charge) exerts an influence on the behavior of these\nparticles.\n\nIn the atomic model, protons are concentrated in the nucleus, while electrons orbit the\nnucleus. The positive charge of the protons attracts the negatively charged electrons,\ncreating a balance that determines the atom's overall charge and stability. This\nattraction can be likened to the gravitational pull of the Sun, which keeps planets in\ntheir orbits.\n\nHowever, it's important to note that the analogy between the solar system and atomic\nstructure is not perfect. For instance, the Sun's gravity is much stronger than the\nelectrostatic forces between protons and electrons. Additionally, the solar system analogy\ndoesn't fully capture the complexities of quantum mechanics and the wave-particle duality\nof electrons. Nonetheless, the analogy can be a useful starting point for understanding\nthe basic concept of charge in atomic structure. If an atom is like a solar system, then\nthe nucleus can be compared to the Sun, and the electrons can be likened to the planets.\nIn this analogy, the nucleus (protons and neutrons) is at the center, just like the Sun,\nand the electrons orbit around it, similar to how planets revolve around the Sun.\n\nThe Sun's gravitational force keeps the planets in their orbits, and similarly, the\npositive charge of the protons in the nucleus attracts the negatively charged electrons,\nholding them in their respective energy levels or orbitals. This attraction is analogous\nto the gravitational pull of the Sun, which keeps the planets in their stable orbits.\n\nHowever, it's crucial to remember that this analogy has limitations. The Sun's gravity is\nmuch stronger than the electrostatic forces between protons and electrons. Moreover, the\nsolar system analogy doesn't account for the wave-particle duality of electrons or the\ncomplexities of quantum mechanics. Despite these limitations, the analogy can serve as a\nhelpful initial understanding of the atomic structure and the role of charge within it."]
# [{'inference': 'If atom is like solar system, then attracts is like...', 'label': 'attracts', 'alternatives': [], 'analogy_type': 'science'}, " If an atom is like the solar system, then attracts can be compared to the gravitational\npull exerted by the Sun. In the atomic model, electrons orbit the nucleus, similar to how\nplanets orbit the Sun. The nucleus, composed of protons and neutrons, exerts a force of\nattraction on the electrons, much like the Sun's gravitational force pulls on the planets.\nThis force keeps the electrons in their respective orbits around the nucleus."]
# [{'inference': 'If atom is like solar system, then revolves is like...', 'label': 'revolves', 'alternatives': [], 'analogy_type': 'science'}, " If an atom is like the solar system, then electrons revolving around the nucleus is like\nplanets revolving around the sun. This analogy helps to understand the structure and\nbehavior of an atom. In this comparison, the nucleus of the atom is similar to the sun,\nwhich is at the center of the solar system. The electrons, which orbit the nucleus, are\nlikened to the planets that revolve around the sun.\n\nHowever, it's important to note that this analogy has its limitations. While it can be\nuseful for visualizing atomic structure, it does not fully capture the complexities of\nelectron behavior. Electrons do not follow fixed orbits like planets around the sun.\nInstead, they exist in regions of probability called electron clouds or orbitals. These\norbitals describe the likelihood of finding an electron in a particular region around the\nnucleus.\n\nIn summary, the analogy of electrons revolving around the nucleus like planets around the\nsun provides a simplified visualization of atomic structure, but it should be understood\nwith the knowledge that electrons behave in a more complex manner than this analogy\nsuggests."]
